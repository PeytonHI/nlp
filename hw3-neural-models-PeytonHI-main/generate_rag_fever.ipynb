# %% [markdown]
# # Retrieval-Augmented Generation

# %%
import json
from qdrant_client import QdrantClient, models
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm

# %%
with open(r"C:\Users\peyto\Desktop\school24\497\hw3\data\fever_train.jsonl", encoding='UTF-8') as fin:
    docs = []
    for line in fin:
        line = line.strip() 
        data = json.loads(line)


        docs.append(data)

# %%
# need a model to generate sentence embeddings for your documents
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
# create a vector database

# client = QdrantClient(":memory:")
client = QdrantClient(path="fever_db")
client.create_collection(
    collection_name="claims",
    vectors_config=models.VectorParams(
        size=model.get_sentence_embedding_dimension(),
        distance=models.Distance.COSINE
    )
)

# %%
# Generate embedding for the claim
# Insert into the vector database
client.upload_points(
    collection_name="claims",
    points=[
        models.PointStruct(
            id = idx,  # Unique ID for the point
            vector = model.encode(f"Claim: {doc['claim']} Label: {doc['label']} Verifiable: {doc['verifiable']} Evidence: {doc['evidence']}"),
            payload=doc  # Metadata (e.g., label)
            #payload = {"claim": doc['claim'], "label": doc['label'], "verifiable": doc['verifiable'], "evidence": doc['evidence']}


        )
        for idx, doc in tqdm(enumerate(docs), total=len(docs))
    ]
)


print("Claims inserted successfully!")

# %%
def query(text):
    hits = client.query_points(
        collection_name="claims",
        query=model.encode(text).tolist(),
        limit=10,
    ).points

    for hit in hits:
        print(hit.payload, "score:", hit.score)

# %%
query(input("Enter a query:"))

# %%
# Write a chatbot with RAG!

import ollama
import json
from qdrant_client import QdrantClient, models
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm

def query(client, model, text):
    hits = client.query_points(
        collection_name="claims",
        query=model.encode(text).tolist(),
        limit=10,
    ).points

    for hit in hits:
        print(hit.payload, "score:", hit.score)
        

    return [hit.payload for hit in hits]
    

def chat(client, model):
    messages = [
        {"role": "system", "content": "You are an expert fact checker who has read all of cv_pairs_fever.tsv"},
    ]

    while True:
        user_input = input("Enter a fact to be checked: ")
        
        # Retrieval
        docs = query(client, model, user_input)
        # Augment
        prompt = "\n".join(f"Claim: {doc['claim']} Label: {doc['label']} Verifiable: {doc['verifiable']} Evidence: {doc['evidence']}" for doc in docs)

        prompt += "\nBased on the above documents, label this query: " + user_input        
        
        messages.append({"role": "user", "content": prompt})

        # Generation
        response = ollama.chat("llama3.2:1b", messages=messages)
        
        print(response["message"]["content"])  # {"role": "assistant", "content": "..."}
        
        messages.append(response["message"])


def main():
    model = SentenceTransformer("all-MiniLM-L6-v2")
    client = QdrantClient(path="fever_db")

    chat(client, model)

# %%
main()
# Out:
# c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# {'id': 30612, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Saif Ali Khan is not male.', 'evidence': [[[46775, 55796, 'Saif_Ali_Khan', 0]], [[46775, 55797, 'Saif_Ali_Khan', 1]]]} score: 0.5886017212242541
# {'id': 30611, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Saif Ali Khan is male.', 'evidence': [[[46776, 55798, 'Saif_Ali_Khan', 1]], [[46776, 55799, 'Saif_Ali_Khan', 6]]]} score: 0.5614247081758342
# {'id': 65904, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Saif Ali Khan is of male gender.', 'evidence': [[[82479, 94259, 'Saif_Ali_Khan', 1]], [[82479, 94260, 'Saif_Ali_Khan', 2]], [[82479, 94261, 'Saif_Ali_Khan', 3]], [[82479, 94262, 'Saif_Ali_Khan', 6]], [[82479, 94263, 'Saif_Ali_Khan', 7]]]} score: 0.5587335883809785
# {'id': 12299, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Leonardo DiCaprio is male.', 'evidence': [[[27591, 33791, 'Leonardo_DiCaprio', 1]], [[27591, 33792, 'Leonardo_DiCaprio', 2]], [[27591, 33793, 'Leonardo_DiCaprio', 0]]]} score: 0.5555774048768078
# {'id': 204526, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Jack Nicholson is male.', 'evidence': [[[241520, 243030, 'Jack_Nicholson', 8]], [[241520, 243031, 'Jack_Nicholson', 5]]]} score: 0.5469546451551698
# {'id': 82055, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Saif Ali Khan is male and he often stars in male roles.', 'evidence': [[[99110, 112220, 'Saif_Ali_Khan', 1]]]} score: 0.529055316467264
# {'id': 124385, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Saif Ali Khan has a gender.', 'evidence': [[[286236, 279730, 'Saif_Ali_Khan', 1], [286236, 279730, 'Son', 0]], [[333041, 319243, 'Saif_Ali_Khan', 1]], [[333081, 319278, 'Saif_Ali_Khan', 0]]]} score: 0.520122077599115
# {'id': 32388, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Eric Trump has a female sibling who is older than him.', 'evidence': [[[48497, 57820, 'Eric_Trump', 1]]]} score: 0.5166287977489972
# {'id': 180062, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Jon Watts is an American male.', 'evidence': [[[209022, 216934, 'Jon_Watts', 0], [209022, 216934, 'Jon_Watts', 3]]]} score: 0.5103179039697301
# {'id': 224891, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Lisa Kudrow was in The Opposite of Sex.', 'evidence': [[[267966, 264605, 'Lisa_Kudrow', 11]]]} score: 0.49143140392729423
# I'll analyze the provided data to label the given claim about Donald Trump.
#
# The claimed information about Donald Trump's gender is as follows:
#
# - Claim: Saif Ali Khan is of male gender.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[82479, 94259, 'Saif_Ali_Khan', 1]], [[82479, 94260, 'Saif_Ali_Khan', 2]], [[82479, 94261, 'Saif_Ali_Khan', 3]], [[82479, 94262, 'Saif_Ali_Khan', 6]], [[82479, 94263, 'Saif_Ali_Khan', 7]]]
#
# - Claim: Leonardo DiCaprio is male.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[27591, 33791, 'Leonardo_DiCaprio', 1]], [[27591, 33792, 'Leonardo_DiCaprio', 2]], [[27591, 33793, 'Leonardo_DiCaprio', 0]]]
#
# - Claim: Jack Nicholson is male.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[241520, 243030, 'Jack_Nicholson', 8]], [[241520, 243031, 'Jack_Nicholson', 5]]]
#
# - Claim: Saif Ali Khan is male and he often stars in male roles.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[99110, 112220, 'Saif_Ali_Khan', 1]]]
#
# - Claim: Eric Trump has a female sibling who is older than him.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[48497, 57820, 'Eric_Trump', 1]]]
#
# - Claim: Jon Watts is an American male.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[209022, 216934, 'Jon_Watts', 0], [209022, 216934, 'Jon_Watts', 3]]]
#
# - Claim: Lisa Kudrow was in The Opposite of Sex.
# - Label: SUPPORTS
# - Verifiable Evidence: [[[267966, 264605, 'Lisa_Kudrow', 11]]]
#
# There is no verifiable evidence to support the claim that Donald Trump is male. All the claims about his gender are based on information from other individuals or films, and none of these sources indicate that he identifies as male. Therefore, I label this query: trump is male as SUPPORTS.
# {'id': 185130, 'verifiable': 'NOT VERIFIABLE', 'label': 'NOT ENOUGH INFO', 'claim': 'Feature advertisement is a division of Davis Entertainment.', 'evidence': [[[215723, None, None, None]]]} score: 0.2868164970307336
# {'id': 96451, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Arrow received awards and nominations.', 'evidence': [[[275880, 270962, 'Arrow_-LRB-TV_series-RRB-', 13]], [[278181, 273071, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325058, 312843, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325059, 312844, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325061, 312845, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325062, 312846, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325068, 312849, 'Arrow_-LRB-TV_series-RRB-', 13]]]} score: 0.2800769635704934
# {'id': 16956, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Community got broadcast syndication in 2013.', 'evidence': [[[32379, 39347, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2644569349935435
# {'id': 42891, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Community got broadcast syndication in 2018.', 'evidence': [[[59206, 69549, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2635562747479149
# {'id': 56529, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Liv Tyler is an entertainer.', 'evidence': [[[72904, 84011, 'Liv_Tyler', 0]], [[72904, 84012, 'Liv_Tyler', 4]], [[72904, 84013, 'Liv_Tyler', 5]], [[72904, 84014, 'Liv_Tyler', 7]], [[72904, 84015, 'Liv_Tyler', 8]], [[72904, 84016, 'Liv_Tyler', 9]], [[72904, 84017, 'Liv_Tyler', 12]], [[72904, 84018, 'Liv_Tyler', 13]], [[72904, 84019, 'Liv_Tyler', 16]]]} score: 0.2597658383474776
# {'id': 110359, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Community got broadcast syndication.', 'evidence': [[[129479, 144224, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2590527714706372
# {'id': 145643, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Ad buyers use jingles in television advertisements.', 'evidence': [[[292246, 285077, 'Jingle', 2]], [[294249, 286581, 'Jingle', 0]], [[294249, 286582, 'Jingle', 2]], [[294875, 287097, 'Jingle', 2]], [[339947, 324756, 'Jingle', 2]], [[339965, 324762, 'Jingle', 2], [339965, 324762, 'Television_advertisement', 0]]]} score: 0.254999459257515
# {'id': 62069, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'In 2013, Community entered broadcast syndication.', 'evidence': [[[78537, 90064, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.25179972957301205
# {'id': 228405, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Archie Panjabi received a nomination for an award.', 'evidence': [[[272497, 268175, 'Archie_Panjabi', 1]]]} score: 0.2504302635217751
# {'id': 209187, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Foxcatcher had zero nominations.', 'evidence': [[[247643, 247937, 'Foxcatcher', 7]], [[247643, 247938, 'Foxcatcher', 8]], [[247643, 247939, 'Foxcatcher', 9]], [[247643, 247940, 'Foxcatcher', 10]], [[247652, 247955, 'Foxcatcher', 9]], [[247652, 247956, 'Foxcatcher', 8]], [[247652, 247957, 'Foxcatcher', 7]], [[247652, 247958, 'Foxcatcher', 10]]]} score: 0.25024166099577405
# I'll analyze the provided data to label the given claim about various topics.
#
# **Claim:** Saif Ali Khan is of male gender.
#
# - Claim: Feature advertisement is a division of Davis Entertainment. Verifiable: VERIFIABLE Evidence: [[[215723, None, None, None]]]
# - Label: NOT ENOUGH INFO
# - Verifiable: NOT VERIFIABLE
#
# **Claim:** Arrow received awards and nominations.
#
# - Claim: Arrow got broadcast syndication in 2013.
#  Verifiable: VERIFIABLE Evidence: [[[32379, 39347, 'Arrow_-LRB-TV_series-RRB-', 15]]]
# - Label: SUPPORTS
# - Verifiable: VERIFIABLE
#
# **Claim:** Community got broadcast syndication in 2013.
#
# - Claim: Community got broadcast syndication in 2018.
#  Refutes: VERIFIABLE Evidence: [[[59206, 69549, 'Community_-LRB-TV_series-RRB-', 15]]]
# - Label: REFUTES
# - Verifiable: VERIFIABLE
#
# **Claim:** Liv Tyler is an entertainer.
#
# - Claim: Community got broadcast syndication in 2018.
#  Refutes: VERIFIABLE Evidence: [[[59206, 69549, 'Community_-LRB-TV_series-RRB-', 15]]]
# - Label: REFUTES
# - Verifiable: VERIFIABLE
#
# **Claim:** Ad buyers use jingles in television advertisements.
#
# - Claim: Feature advertisement is a division of Davis Entertainment.
#  Refutes: VERIFIABLE Evidence: [[[292246, 285077, 'Jingle', 2]], [[294249, 286581, 'Jingle', 0]], [[294249, 286582, 'Jingle', 2]], [[294875, 287097, 'Jingle', 2]], [[339947, 324756, 'Jingle', 2]], [[339965, 324762, 'Jingle', 2], [339965, 324762, 'Television_advertisement', 0]]]
# - Label: SUPPORTS
# - Verifiable: VERIFIABLE
#
# **Claim:** Archie Panjabi received a nomination for an award.
#
# - Claim: Community got broadcast syndication in 2018.
#  Refutes: VERIFIABLE Evidence: [[[272497, 268175, 'Archie_Panjabi', 1]]]
# - Label: SUPPORTS
# - Verifiable: VERIFIABLE
#
# Based on the above documents:
#
# * Saif Ali Khan's gender is not mentioned or verified in any of the sources.
# * Arrow did receive awards and nominations, so this claim is supported.
# * Community got broadcast syndication in both 2013 and 2018, but only the 2013 claim is verifiable.
# * Liv Tyler was an actress, but her profession as an entertainer is not mentioned or verified in any of the sources.
# * Ad buyers do use jingles in television advertisements, so this claim is supported.
#
# Therefore, I will label the query:
#
# "Saif Ali Khan's gender: NOT ENOUGH INFO"
#
# Note that this answer does not provide a definitive answer to the question, as Saif Ali Khan's gender remains unknown.
# {'id': 185130, 'verifiable': 'NOT VERIFIABLE', 'label': 'NOT ENOUGH INFO', 'claim': 'Feature advertisement is a division of Davis Entertainment.', 'evidence': [[[215723, None, None, None]]]} score: 0.2868164970307336
# {'id': 96451, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Arrow received awards and nominations.', 'evidence': [[[275880, 270962, 'Arrow_-LRB-TV_series-RRB-', 13]], [[278181, 273071, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325058, 312843, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325059, 312844, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325061, 312845, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325062, 312846, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325068, 312849, 'Arrow_-LRB-TV_series-RRB-', 13]]]} score: 0.2800769635704934
# {'id': 16956, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Community got broadcast syndication in 2013.', 'evidence': [[[32379, 39347, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2644569349935435
# {'id': 42891, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Community got broadcast syndication in 2018.', 'evidence': [[[59206, 69549, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2635562747479149
# {'id': 56529, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Liv Tyler is an entertainer.', 'evidence': [[[72904, 84011, 'Liv_Tyler', 0]], [[72904, 84012, 'Liv_Tyler', 4]], [[72904, 84013, 'Liv_Tyler', 5]], [[72904, 84014, 'Liv_Tyler', 7]], [[72904, 84015, 'Liv_Tyler', 8]], [[72904, 84016, 'Liv_Tyler', 9]], [[72904, 84017, 'Liv_Tyler', 12]], [[72904, 84018, 'Liv_Tyler', 13]], [[72904, 84019, 'Liv_Tyler', 16]]]} score: 0.2597658383474776
# {'id': 110359, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Community got broadcast syndication.', 'evidence': [[[129479, 144224, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2590527714706372
# {'id': 145643, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Ad buyers use jingles in television advertisements.', 'evidence': [[[292246, 285077, 'Jingle', 2]], [[294249, 286581, 'Jingle', 0]], [[294249, 286582, 'Jingle', 2]], [[294875, 287097, 'Jingle', 2]], [[339947, 324756, 'Jingle', 2]], [[339965, 324762, 'Jingle', 2], [339965, 324762, 'Television_advertisement', 0]]]} score: 0.254999459257515
# {'id': 62069, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'In 2013, Community entered broadcast syndication.', 'evidence': [[[78537, 90064, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.25179972957301205
# {'id': 228405, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Archie Panjabi received a nomination for an award.', 'evidence': [[[272497, 268175, 'Archie_Panjabi', 1]]]} score: 0.2504302635217751
# {'id': 209187, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Foxcatcher had zero nominations.', 'evidence': [[[247643, 247937, 'Foxcatcher', 7]], [[247643, 247938, 'Foxcatcher', 8]], [[247643, 247939, 'Foxcatcher', 9]], [[247643, 247940, 'Foxcatcher', 10]], [[247652, 247955, 'Foxcatcher', 9]], [[247652, 247956, 'Foxcatcher', 8]], [[247652, 247957, 'Foxcatcher', 7]], [[247652, 247958, 'Foxcatcher', 10]]]} score: 0.25024166099577405
# "Saif Ali Khan's gender: NOT ENOUGH INFO"
#
# This answer does not provide a definitive answer to the question about Saif Ali Khan's gender. The available information is limited, and there is no clear evidence to confirm or deny his gender.
#
# The other claims can be analyzed as follows:
#
# * Arrow received awards and nominations: SUPPORTS
# * Community got broadcast syndication in both 2013 and 2018: VERIFIABLE
# * Liv Tyler is an entertainer: SUPPORTS
# * Ad buyers use jingles in television advertisements: SUPPORTS
# * In 2013, Community entered broadcast syndication: SUPPORTS
# * Archie Panjabi received a nomination for an award: SUPPORTS
#
# However, the claim about community got broadcast syndication in 2018: REFUTES is incorrect because it actually supports this claim.
#
# Therefore, I will label the query as:
#
# "Saif Ali Khan's gender: NOT ENOUGH INFO"
# {'id': 185130, 'verifiable': 'NOT VERIFIABLE', 'label': 'NOT ENOUGH INFO', 'claim': 'Feature advertisement is a division of Davis Entertainment.', 'evidence': [[[215723, None, None, None]]]} score: 0.2868164970307336
# {'id': 96451, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Arrow received awards and nominations.', 'evidence': [[[275880, 270962, 'Arrow_-LRB-TV_series-RRB-', 13]], [[278181, 273071, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325058, 312843, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325059, 312844, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325061, 312845, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325062, 312846, 'Arrow_-LRB-TV_series-RRB-', 13]], [[325068, 312849, 'Arrow_-LRB-TV_series-RRB-', 13]]]} score: 0.2800769635704934
# {'id': 16956, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Community got broadcast syndication in 2013.', 'evidence': [[[32379, 39347, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2644569349935435
# {'id': 42891, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Community got broadcast syndication in 2018.', 'evidence': [[[59206, 69549, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2635562747479149
# {'id': 56529, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Liv Tyler is an entertainer.', 'evidence': [[[72904, 84011, 'Liv_Tyler', 0]], [[72904, 84012, 'Liv_Tyler', 4]], [[72904, 84013, 'Liv_Tyler', 5]], [[72904, 84014, 'Liv_Tyler', 7]], [[72904, 84015, 'Liv_Tyler', 8]], [[72904, 84016, 'Liv_Tyler', 9]], [[72904, 84017, 'Liv_Tyler', 12]], [[72904, 84018, 'Liv_Tyler', 13]], [[72904, 84019, 'Liv_Tyler', 16]]]} score: 0.2597658383474776
# {'id': 110359, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Community got broadcast syndication.', 'evidence': [[[129479, 144224, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.2590527714706372
# {'id': 145643, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Ad buyers use jingles in television advertisements.', 'evidence': [[[292246, 285077, 'Jingle', 2]], [[294249, 286581, 'Jingle', 0]], [[294249, 286582, 'Jingle', 2]], [[294875, 287097, 'Jingle', 2]], [[339947, 324756, 'Jingle', 2]], [[339965, 324762, 'Jingle', 2], [339965, 324762, 'Television_advertisement', 0]]]} score: 0.254999459257515
# {'id': 62069, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'In 2013, Community entered broadcast syndication.', 'evidence': [[[78537, 90064, 'Community_-LRB-TV_series-RRB-', 15]]]} score: 0.25179972957301205
# {'id': 228405, 'verifiable': 'VERIFIABLE', 'label': 'SUPPORTS', 'claim': 'Archie Panjabi received a nomination for an award.', 'evidence': [[[272497, 268175, 'Archie_Panjabi', 1]]]} score: 0.2504302635217751
# {'id': 209187, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'Foxcatcher had zero nominations.', 'evidence': [[[247643, 247937, 'Foxcatcher', 7]], [[247643, 247938, 'Foxcatcher', 8]], [[247643, 247939, 'Foxcatcher', 9]], [[247643, 247940, 'Foxcatcher', 10]], [[247652, 247955, 'Foxcatcher', 9]], [[247652, 247956, 'Foxcatcher', 8]], [[247652, 247957, 'Foxcatcher', 7]], [[247652, 247958, 'Foxcatcher', 10]]]} score: 0.25024166099577405
# "Feature advertisement is a division of Davis Entertainment: VERIFIABLE"
#
# The evidence supporting this claim includes:
#
# * The existence of a division called "Davis Entertainment" in the context of television advertising.
# * The mention of "jingles" and "television advertisements" as areas of focus within Davis Entertainment.
#
# However, it's worth noting that the other claims listed appear to be specific details about individual events or projects (e.g. awards, nominations, broadcast syndication) rather than broader divisions or organizations. Therefore, I would categorize this query as:
#
# "Feature advertisement is a division of Davis Entertainment: VERIFIABLE"
#
# This answer accurately represents the available information and provides a clear and concise statement regarding the relationship between feature advertisements and Davis Entertainment.
