# %% [markdown]
# # Retrieval-Augmented Generation

# %%
import json
from qdrant_client import QdrantClient, models
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm

# %%
with open(r"C:\Users\peyto\Desktop\school24\497\hw3\data\cv_pairs.tsv", encoding='UTF-8') as fin:
    docs = []
    for line in fin:
        line = line.strip() 
        data = json.loads(line)
        claim = data[0]['content']
        label = data[1]['content']
        new_dict = {'claim': claim, 'label': label}
        docs.append(new_dict)

# %%
# need a model to generate sentence embeddings for your documents
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
# create a vector database

# client = QdrantClient(":memory:")
client = QdrantClient(path="generated_db")
client.create_collection(
    collection_name="claims",
    vectors_config=models.VectorParams(
        size=model.get_sentence_embedding_dimension(),
        distance=models.Distance.COSINE
    )
)

# %%
# Generate embedding for the claim
# Insert into the vector database
client.upload_points(
    collection_name="claims",
    points=[
        models.PointStruct(
            id = idx,  # Unique ID for the point
            vector = model.encode(f"Claim: {doc['claim']} Label: {doc['label']}"),
            payload=doc

        )
        for idx, doc in tqdm(enumerate(docs), total=len(docs))
    ]
)


print("Claims inserted successfully!")

# %%
def query(text):
    hits = client.query_points(
        collection_name="claims",
        query=model.encode(text).tolist(),
        limit=10,
    ).points

    for hit in hits:
        print(hit.payload, "score:", hit.score)

# %%
query(input("Enter a query:"))

# %%
# Write a chatbot with RAG!

import ollama
import json
from qdrant_client import QdrantClient, models
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm

def query(client, model, text):
    hits = client.query_points(
        collection_name="claims",
        query=model.encode(text).tolist(),
        limit=10,
    ).points

    for hit in hits:
        print(hit.payload, "score:", hit.score)
        

    return [hit.payload for hit in hits]
    

def chat(client, model):
    messages = [
        {"role": "system", "content": "You are an expert fact checker who has read all of cv_pairs.tsv"},
    ]

    while True:
        user_input = input("Enter a fact to be checked: ")
        
        # Retrieval
        docs = query(client, model, user_input)
        # Augment
        prompt = "\n".join(f"Claim: {doc['claim']}\nLabel: {doc['label']}" for doc in docs)
        # prompt = "\n".join(doc['label'] for doc in docs)

        prompt += "\nBased on the above documents, label this query: " + user_input        
        
        messages.append({"role": "user", "content": prompt})

        # Generation
        response = ollama.chat("llama3.2:1b", messages=messages)
        
        print(response["message"]["content"])  # {"role": "assistant", "content": "..."}
        
        messages.append(response["message"])


def main():
    model = SentenceTransformer("all-MiniLM-L6-v2")
    client = QdrantClient(path="generated_db")

    chat(client, model)

# %%
main()
# Out:
# c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# {'claim': 'Ellyse Tait Perry is a male person.', 'label': 'REFUTES'} score: 0.47602566745891617
# {'claim': 'Mariah Carey is an exclusively male artist.', 'label': 'REFUTES'} score: 0.4680137115734803
# {'claim': "Eric Trump, Donald Trump's eldest son, is reportedly not the President of the United States but he is one of his children.", 'label': 'SUPPORTS'} score: 0.4638487745926932
# {'claim': 'Chris Hemsworth is a woman.', 'label': 'NOT ENOUGH INFO'} score: 0.4589462011100838
# {'claim': "Eric Trump is Donald Trump's third son.", 'label': 'REFUTES'} score: 0.4517393666325805
# {'claim': 'Jordan Spence is a woman.', 'label': 'NOT ENOUGH INFO'} score: 0.43720496912519935
# {'claim': 'Donald Trump Jr. is the son of Frederick Christ Trump II, not Fred Trump.', 'label': 'REFUTES'} score: 0.42890498788595804
# {'claim': 'Jennifer Aniston is a man.', 'label': 'NOT ENOUGH Info'} score: 0.42725551128422495
# {'claim': "Ileana D'Cruz is a man.", 'label': 'REFUTES'} score: 0.4247643473189578
# {'claim': "Eric Trump's father, Donald Trump, was the 45th President of the United States, making Eric Trump his older brother, not his second son.", 'label': 'REFUTES'} score: 0.41918304702877907
# I'll do my best to analyze the claims and provide a well-informed label.
#
# **Claim:** Donald Trump was born in Queens, New York.
# **Label:** SUPPORTS
#
# This claim can be verified through publicly available information, such as his birth certificate or biographies. The claim is supported by substantial evidence, making "SUPPORTS" the most accurate label.
#
# **Claim:** Mariah Carey's maiden name is Stevens.
# **Label:** REFUTES
#
# Mariah Carey was born Mariah Teresa Carey in Huntington, New York. Her maiden name is indeed Stevens, not Carey. This claim can be verified through publicly available information, such as her birth certificate or biographies. The claim is refuted by evidence, making "REFUTES" the most accurate label.
#
# **Claim:** Eric Trump's father was Fred Trump.
# **Label:** REFUTES
#
# According to various sources, including Donald Trump's biography and other reliable outlets, Eric Trump's father was Frederick Christ "Freddie" Trump, not Fred Trump. This claim is refuted by evidence, making "REFUTES" the most accurate label.
#
# **Claim:** Chris Hemsworth's mother was Australian.
# **Label:** NOT ENOUGH INFO
#
# Chris Hemsworth's parents are Craig Hawker and Jane Horrocks. While there may be some information about his maternal lineage, it is not clear whether he has an Australian mother or not. This claim requires more information to make a judgment call, making "NOT ENOUGH INFO" the most accurate label.
#
# **Claim:** Ileana D'Cruz's mother was Indian.
# **Label:** NOT ENOUGH INFO
#
# Ileana D'Cruz's parents are Tom D'Arcy and Lorraine D'Cruz. While there may be some information about her maternal lineage, it is not clear whether she has an Indian mother or not. This claim requires more information to make a judgment call, making "NOT ENOUGH INFO" the most accurate label.
#
# **Claim:** Eric Trump's father was Fred Trump.
# **Label:** REFUTES
#
# This claim is refuted by evidence, as mentioned earlier. The correct statement is that Eric Trump's father was Frederick Christ "Freddie" Trump, not Fred Trump.
#
# These labels are based on my analysis of the available information and the claims themselves. If more context or evidence is provided, it may change the labels accordingly.
# {'claim': 'Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.', 'label': 'SUPPORTS'} score: 0.2526286976266385
# {'claim': 'Hayden Parris has sponsored advertising on TV.', 'label': 'REFUTES'} score: 0.2477765893912085
# {'claim': 'Community got aired on a cable television network.', 'label': 'REFUTES'} score: 0.23747014566428962
# {'claim': 'Avatar: The Last Airbender has over 250 episodes.', 'label': 'SUPPORTS'} score: 0.22909084343013647
# {'claim': 'SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."', 'label': 'SUPPORTS'} score: 0.2255534131725468
# {'claim': 'Lucas Oil Stadium hosted Super Bowl XLVIII.', 'label': 'REFUTES'} score: 0.2240843437514437
# {'claim': 'A contestant on The X Factor won the competition.', 'label': 'REFUTES'} score: 0.22340039329873873
# {'claim': 'Penguin Random House publishes Thirteen Reasons Why.', 'label': 'REFUTES'} score: 0.22032899711464285
# {'claim': 'Cars Toons is computer-animated.', 'label': 'NOT ENOUGH INFO'} score: 0.21947949547786902
# {'claim': 'Giada Di Enzo appears on the $5 bill.', 'label': 'SUPPORTS'} score: 0.21790821899527119
# I'll do my best to analyze the claims and provide a well-informed label.
#
# **Claim:** Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.
# **Label:** SUPPORTS
#
# This claim is likely true, as the show's creators have stated that they chose not to pursue broadcast syndication due to concerns about maintaining creative control. The show has also been renewed through subsequent seasons, suggesting a strong commercial foundation.
#
# **Claim:** Hayden Parris has sponsored advertising on TV.
# **Label:** REFUTES
#
# I couldn't find any information confirming Hayden Parris as an actor or spokesperson who sponsors TV advertising. This claim appears to be unsubstantiated and likely false.
#
# **Claim:** Community got aired on a cable television network.
# **Label:** REFUTES
#
# Community actually airs on NBC, not a cable network. It was a flagship series for the network's "Must See TV" lineup in its early seasons but was later moved to a Friday night time slot in the 2014-15 season.
#
# **Claim:** Avatar: The Last Airbender has over 250 episodes.
# **Label:** SUPPORTS
#
# This claim is likely true, as the show originally aired from 2005 to 2008 and had an extensive production run. According to the series' official website, a total of 73 episodes were produced during its original run.
#
# **Claim:** SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement.
# **Label:** SUPPORTS
#
# This claim appears to be true. In January 2021, Elon Musk announced that his company was expanding its programs to include internships and fellowships for students from underrepresented groups.
#
# **Claim:** Lucas Oil Stadium hosted Super Bowl XLVIII.
# **Label:** REFUTES
#
# While the stadium is located in Indianapolis, Indiana (not a typical NFL city), I couldn't find any evidence that it hosted Super Bowl XLVIII. The game was played at MetLife Stadium in East Rutherford, New Jersey.
#
# **Claim:** A contestant on The X Factor won the competition.
# **Label:** REFUTES
#
# I couldn't find any information about a contestant on The X Factor winning the competition. While the show has had its share of winners and finalists over the years, I couldn't verify this specific claim.
#
# **Claim:** Penguin Random House publishes Thirteen Reasons Why.
# **Label:** REFUTES
#
# Penguin Random House is one of many major book publishers in the United States, but I couldn't find any evidence that they publish The Perks of Being a Wallflower (not Thirteen Reasons Why), which was actually published by Little, Brown Books for Young Readers.
#
# **Claim:** Cars Toons is computer-animated.
# **Label:** NOT ENOUGH INFO
#
# I couldn't verify this claim with any reliable sources. While Cars is indeed an animated series, I couldn't find any information about it being "computer-animated". This could be a misattribution or inaccuracy.
#
# **Claim:** Giada Di Enzo appears on the $5 bill.
# **Label:** SUPPORTS
#
# I couldn't find any evidence that Giada Di Enzo has appeared on the United States penny (not the $5 bill). The official obverse (front side) of the current US penny features George Washington, while other denominations feature various notable figures.
#
# Based on these analyses, I'll provide labels for each query:
#
# 1. SUPPORTS: Community
# 2. REFUTES: Hayden Parris, Lucas Oil Stadium, Cars Toons, Giada Di Enzo
# 3. NOT ENOUGH INFO: Avatar: The Last Airbender
# {'claim': 'Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.', 'label': 'SUPPORTS'} score: 0.2526286976266385
# {'claim': 'Hayden Parris has sponsored advertising on TV.', 'label': 'REFUTES'} score: 0.2477765893912085
# {'claim': 'Community got aired on a cable television network.', 'label': 'REFUTES'} score: 0.23747014566428962
# {'claim': 'Avatar: The Last Airbender has over 250 episodes.', 'label': 'SUPPORTS'} score: 0.22909084343013647
# {'claim': 'SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."', 'label': 'SUPPORTS'} score: 0.2255534131725468
# {'claim': 'Lucas Oil Stadium hosted Super Bowl XLVIII.', 'label': 'REFUTES'} score: 0.2240843437514437
# {'claim': 'A contestant on The X Factor won the competition.', 'label': 'REFUTES'} score: 0.22340039329873873
# {'claim': 'Penguin Random House publishes Thirteen Reasons Why.', 'label': 'REFUTES'} score: 0.22032899711464285
# {'claim': 'Cars Toons is computer-animated.', 'label': 'NOT ENOUGH INFO'} score: 0.21947949547786902
# {'claim': 'Giada Di Enzo appears on the $5 bill.', 'label': 'SUPPORTS'} score: 0.21790821899527119
# I'll do my best to analyze the claims and provide a well-informed label.
#
# **Claim:** Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.
# **Label:** SUPPORTS
#
# This claim is likely true. Although NBC ultimately canceled the show after four seasons, the network did manage to acquire a significant amount of rights for reruns due to its popularity.
#
# **Claim:** Hayden Parris has sponsored advertising on TV.
# **Label:** REFUTES
#
# I couldn't find any information confirming Hayden Parris as an actor or spokesperson who sponsors TV advertising. This claim appears to be unsubstantiated and likely false.
#
# **Claim:** Community got aired on a cable television network.
# **Label:** REFUTES
#
# Community actually airs on NBC, not a cable network. It was originally broadcast on NBC but later moved to G4 (a technology-focused cable network) in its final season.
#
# **Claim:** Avatar: The Last Airbender has over 250 episodes.
# **Label:** SUPPORTS
#
# This claim is likely true. The show had an extensive production run and aired for 73 episodes during its original run on Nickelodeon from 2005 to 2008.
#
# **Claim:** SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement.
# **Label:** SUPPORTS
#
# This claim appears to be true. In January 2021, Elon Musk announced that his company was expanding its programs to include internships and fellowships for students from underrepresented groups.
#
# **Claim:** Lucas Oil Stadium hosted Super Bowl XLVIII.
# **Label:** REFUTES
#
# While the stadium is located in Indianapolis, Indiana (not a typical NFL city), I couldn't find any evidence that it hosted Super Bowl XLVIII. The game was played at MetLife Stadium in East Rutherford, New Jersey.
#
# **Claim:** A contestant on The X Factor won the competition.
# **Label:** REFUTES
#
# I couldn't find any information about a contestant on The X Factor winning the competition. While the show has had its share of winners and finalists over the years, I couldn't verify this specific claim.
#
# **Claim:** Penguin Random House publishes Thirteen Reasons Why.
# **Label:** REFUTES
#
# Penguin Random House is one of many major book publishers in the United States, but I couldn't find any evidence that they publish The Perks of Being a Wallflower (not Thirteen Reasons Why), which was actually published by Little, Brown Books for Young Readers.
#
# **Claim:** Cars Toons is computer-animated.
# **Label:** NOT ENOUGH INFO
#
# I couldn't verify this claim with any reliable sources. While Cars is indeed an animated series, I couldn't find any information about it being "computer-animated". This could be a misattribution or inaccuracy.
#
# **Claim:** Giada Di Enzo appears on the $5 bill.
# **Label:** SUPPORTS
#
# I couldn't find any evidence that Giada Di Enzo has appeared on the United States penny (not the $5 bill). The official obverse (front side) of the current US penny features George Washington, while other denominations feature various notable figures.
#
# Based on these analyses, I'll provide labels for each query:
#
# 1. SUPPORTS: Community
# 2. REFUTES: Hayden Parris, Lucas Oil Stadium, Cars Toons, Giada Di Enzo, SpaceX
# 3. NOT ENOUGH INFO: Avatar: The Last Airbender
# {'claim': 'Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.', 'label': 'SUPPORTS'} score: 0.2526286976266385
# {'claim': 'Hayden Parris has sponsored advertising on TV.', 'label': 'REFUTES'} score: 0.2477765893912085
# {'claim': 'Community got aired on a cable television network.', 'label': 'REFUTES'} score: 0.23747014566428962
# {'claim': 'Avatar: The Last Airbender has over 250 episodes.', 'label': 'SUPPORTS'} score: 0.22909084343013647
# {'claim': 'SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."', 'label': 'SUPPORTS'} score: 0.2255534131725468
# {'claim': 'Lucas Oil Stadium hosted Super Bowl XLVIII.', 'label': 'REFUTES'} score: 0.2240843437514437
# {'claim': 'A contestant on The X Factor won the competition.', 'label': 'REFUTES'} score: 0.22340039329873873
# {'claim': 'Penguin Random House publishes Thirteen Reasons Why.', 'label': 'REFUTES'} score: 0.22032899711464285
# {'claim': 'Cars Toons is computer-animated.', 'label': 'NOT ENOUGH INFO'} score: 0.21947949547786902
# {'claim': 'Giada Di Enzo appears on the $5 bill.', 'label': 'SUPPORTS'} score: 0.21790821899527119
# I'll do my best to analyze the claims and provide a well-informed label.
#
# **Claim:** Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.
# **Label:** SUPPORTS
#
# This claim is likely true. Although NBC ultimately canceled the show after four seasons, the network did manage to acquire a significant amount of rights for reruns due to its popularity.
#
# **Claim:** Hayden Parris has sponsored advertising on TV.
# **Label:** REFUTES
#
# I couldn't find any information confirming Hayden Parris as an actor or spokesperson who sponsors TV advertising. This claim appears to be unsubstantiated and likely false.
#
# **Claim:** Community got aired on a cable television network.
# **Label:** REFUTES
#
# Community actually airs on NBC, not a cable network. It was originally broadcast on NBC but later moved to G4 (a technology-focused cable network) in its final season.
#
# **Claim:** Avatar: The Last Airbender has over 250 episodes.
# **Label:** SUPPORTS
#
# This claim is likely true. The show had an extensive production run and aired for 73 episodes during its original run on Nickelodeon from 2005 to 2008.
#
# **Claim:** SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."
# **Label:** SUPPORTS
#
# This claim appears to be true. In January 2021, Elon Musk announced that his company was expanding its programs to include internships and fellowships for students from underrepresented groups.
#
# **Claim:** Lucas Oil Stadium hosted Super Bowl XLVIII.
# **Label:** REFUTES
#
# While the stadium is located in Indianapolis, Indiana (not a typical NFL city), I couldn't find any evidence that it hosted Super Bowl XLVIII. The game was played at MetLife Stadium in East Rutherford, New Jersey.
#
# **Claim:** A contestant on The X Factor won the competition.
# **Label:** REFUTES
#
# I couldn't find any information about a contestant on The X Factor winning the competition. While the show has had its share of winners and finalists over the years, I couldn't verify this specific claim.
#
# **Claim:** Penguin Random House publishes Thirteen Reasons Why.
# **Label:** REFUTES
#
# Penguin Random House is one of many major book publishers in the United States, but I couldn't find any evidence that they publish The Perks of Being a Wallflower (not Thirteen Reasons Why), which was actually published by Little, Brown Books for Young Readers.
#
# **Claim:** Cars Toons is computer-animated.
# **Label:** NOT ENOUGH INFO
#
# I couldn't verify this claim with any reliable sources. While Cars is indeed an animated series, I couldn't find any information about it being "computer-animated". This could be a misattribution or inaccuracy.
#
# **Claim:** Giada Di Enzo appears on the $5 bill.
# **Label:** SUPPORTS
#
# I couldn't find any evidence that Giada Di Enzo has appeared on the United States penny (not the $5 bill). The official obverse (front side) of the current US penny features George Washington, while other denominations feature various notable figures.
#
# Based on these analyses, I'll provide labels for each query:
#
# 1. SUPPORTS: Community
# 2. REFUTES: Hayden Parris, Lucas Oil Stadium, Cars Toons, Giada Di Enzo, SpaceX, Avatar: The Last Airbender, X Factor
# 3. NOT ENOUGH INFO: Avatar: The Last Airbender
# {'claim': 'Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.', 'label': 'SUPPORTS'} score: 0.2526286976266385
# {'claim': 'Hayden Parris has sponsored advertising on TV.', 'label': 'REFUTES'} score: 0.2477765893912085
# {'claim': 'Community got aired on a cable television network.', 'label': 'REFUTES'} score: 0.23747014566428962
# {'claim': 'Avatar: The Last Airbender has over 250 episodes.', 'label': 'SUPPORTS'} score: 0.22909084343013647
# {'claim': 'SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."', 'label': 'SUPPORTS'} score: 0.2255534131725468
# {'claim': 'Lucas Oil Stadium hosted Super Bowl XLVIII.', 'label': 'REFUTES'} score: 0.2240843437514437
# {'claim': 'A contestant on The X Factor won the competition.', 'label': 'REFUTES'} score: 0.22340039329873873
# {'claim': 'Penguin Random House publishes Thirteen Reasons Why.', 'label': 'REFUTES'} score: 0.22032899711464285
# {'claim': 'Cars Toons is computer-animated.', 'label': 'NOT ENOUGH INFO'} score: 0.21947949547786902
# {'claim': 'Giada Di Enzo appears on the $5 bill.', 'label': 'SUPPORTS'} score: 0.21790821899527119
# I'll do my best to analyze the claims and provide a well-informed label.
#
# **Claim:** Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.
# **Label:** SUPPORTS
#
# This claim is likely true. Although NBC ultimately canceled the show after four seasons, the network did manage to acquire a significant amount of rights for reruns due to its popularity.
#
# **Claim:** Hayden Parris has sponsored advertising on TV.
# **Label:** REFUTES
#
# I couldn't find any information confirming Hayden Parris as an actor or spokesperson who sponsors TV advertising. This claim appears to be unsubstantiated and likely false.
#
# **Claim:** Community got aired on a cable television network.
# **Label:** REFUTES
#
# Community actually airs on NBC, not a cable network. It was originally broadcast on NBC but later moved to G4 (a technology-focused cable network) in its final season.
#
# **Claim:** Avatar: The Last Airbender has over 250 episodes.
# **Label:** SUPPORTS
#
# This claim is likely true. The show had an extensive production run and aired for 73 episodes during its original run on Nickelodeon from 2005 to 2008.
#
# **Claim:** SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."
# **Label:** SUPPORTS
#
# This claim appears to be true. In January 2021, Elon Musk announced that his company was expanding its programs to include internships and fellowships for students from underrepresented groups.
#
# **Claim:** Lucas Oil Stadium hosted Super Bowl XLVIII.
# **Label:** REFUTES
#
# While the stadium is located in Indianapolis, Indiana (not a typical NFL city), I couldn't find any evidence that it hosted Super Bowl XLVIII. The game was played at MetLife Stadium in East Rutherford, New Jersey.
#
# **Claim:** A contestant on The X Factor won the competition.
# **Label:** REFUTES
#
# I couldn't find any information about a contestant on The X Factor winning the competition. While the show has had its share of winners and finalists over the years, I couldn't verify this specific claim.
#
# **Claim:** Penguin Random House publishes Thirteen Reasons Why.
# **Label:** REFUTES
#
# Penguin Random House is one of many major book publishers in the United States, but I couldn't find any evidence that they publish The Perks of Being a Wallflower (not Thirteen Reasons Why), which was actually published by Little, Brown Books for Young Readers.
#
# **Claim:** Cars Toons is computer-animated.
# **Label:** NOT ENOUGH INFO
#
# I couldn't verify this claim with any reliable sources. While Cars is indeed an animated series, I couldn't find any information about it being "computer-animated". This could be a misattribution or inaccuracy.
#
# **Claim:** Giada Di Enzo appears on the $5 bill.
# **Label:** SUPPORTS
#
# I couldn't find any evidence that Giada Di Enzo has appeared on the United States penny (not the $5 bill). The official obverse (front side) of the current US penny features George Washington, while other denominations feature various notable figures.
#
# Based on these analyses, I'll provide labels for each query:
#
# 1. SUPPORTS: Community
# 2. REFUTES: Hayden Parris, Lucas Oil Stadium, Cars Toons, Giada Di Enzo, SpaceX, Avatar: The Last Airbender, X Factor
# 3. NOT ENOUGH INFO: Avatar: The Last Airbender
# {'claim': 'Community has yet to successfully transition its television show to public broadcasting through the "broadcast syndication" model, allowing it to maintain control over its content distribution and avoid potential changes in ownership or creative direction.', 'label': 'SUPPORTS'} score: 0.2526286976266385
# {'claim': 'Hayden Parris has sponsored advertising on TV.', 'label': 'REFUTES'} score: 0.2477765893912085
# {'claim': 'Community got aired on a cable television network.', 'label': 'REFUTES'} score: 0.23747014566428962
# {'claim': 'Avatar: The Last Airbender has over 250 episodes.', 'label': 'SUPPORTS'} score: 0.22909084343013647
# {'claim': 'SpaceX is committed to empowering individuals from diverse backgrounds and skill sets to contribute to its ambitious mission, leveraging volunteer opportunities as a means to foster innovation, collaboration, and community engagement."', 'label': 'SUPPORTS'} score: 0.2255534131725468
# {'claim': 'Lucas Oil Stadium hosted Super Bowl XLVIII.', 'label': 'REFUTES'} score: 0.2240843437514437
# {'claim': 'A contestant on The X Factor won the competition.', 'label': 'REFUTES'} score: 0.22340039329873873
# {'claim': 'Penguin Random House publishes Thirteen Reasons Why.', 'label': 'REFUTES'} score: 0.22032899711464285
# {'claim': 'Cars Toons is computer-animated.', 'label': 'NOT ENOUGH INFO'} score: 0.21947949547786902
# {'claim': 'Giada Di Enzo appears on the $5 bill.', 'label': 'SUPPORTS'} score: 0.21790821899527119
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main()
#
# Cell In[1], line 53, in main()
#      50 model = SentenceTransformer("all-MiniLM-L6-v2")
#      51 client = QdrantClient(path="generated_db")
# ---> 53 chat(client, model)
#
# Cell In[1], line 42, in chat(client, model)
#      39 messages.append({"role": "user", "content": prompt})
#      41 # Generation
# ---> 42 response = ollama.chat("llama3.2:1b", messages=messages)
#      44 print(response["message"]["content"])  # {"role": "assistant", "content": "..."}
#      46 messages.append(response["message"])
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:331, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     286 def chat(
#     287   self,
#     288   model: str = '',
#    (...)
#     295   keep_alive: Optional[Union[float, str]] = None,
#     296 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     297   """
#     298   Create a chat response using the requested model.
#     299
#    (...)
#     328   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     329   """
# --> 331   return self._request(
#     332     ChatResponse,
#     333     'POST',
#     334     '/api/chat',
#     335     json=ChatRequest(
#     336       model=model,
#     337       messages=[message for message in _copy_messages(messages)],
#     338       tools=[tool for tool in _copy_tools(tools)],
#     339       stream=stream,
#     340       format=format,
#     341       options=options,
#     342       keep_alive=keep_alive,
#     343     ).model_dump(exclude_none=True),
#     344     stream=stream,
#     345   )
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:175, in Client._request(self, cls, stream, *args, **kwargs)
#     171         yield cls(**part)
#     173   return inner()
# --> 175 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:116, in Client._request_raw(self, *args, **kwargs)
#     115 def _request_raw(self, *args, **kwargs):
# --> 116   r = self._client.request(*args, **kwargs)
#     117   try:
#     118     r.raise_for_status()
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\peyto\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
